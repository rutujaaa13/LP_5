# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
# Load data

columns = ['letter'] + [f'feature_{i}' for i in range(1,17)]

df = pd.read_csv("letter-recognition.csv")

print(df.head())
# Out:
#   letter  xbox   ybox   width   height  onpix   xbar   ybar   x2bar  y2bar   \
# 0      T      2      8       3       5       1      8     13      0       6
# 1      I      5     12       3       7       2     10      5      5       4
# 2      D      4     11       6       8       6     10      6      2       6
# 3      N      7     11       6       6       3      5      9      4       6
# 4      G      2      1       3       1       1      8      6      6       6
#
#    xybar   x2ybar  xy2bar  xedge   xedgey  yedge   yedgex
# 0       6      10       8       0       8       0       8
# 1      13       3       9       2       8       4      10
# 2      10       3       7       3       7       3       9
# 3       4       4      10       6      10       2       8
# 4       6       5       9       1       7       5      10

# %%
X = df.iloc[:, 1:].values
y = df.iloc[:, 0].values

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
y_categorical = to_categorical(y_encoded)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_categorical, test_size=0.2, random_state=42
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

model = Sequential()

model.add(Input(shape=(16,)))   
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(26, activation='softmax'))

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5689 - loss: 1.5895 - val_accuracy: 0.7447 - val_loss: 0.9168
# Epoch 2/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7846 - loss: 0.7417 - val_accuracy: 0.8159 - val_loss: 0.6529
# Epoch 3/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8386 - loss: 0.5550 - val_accuracy: 0.8472 - val_loss: 0.5107
# Epoch 4/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8667 - loss: 0.4490 - val_accuracy: 0.8728 - val_loss: 0.4278
# Epoch 5/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8902 - loss: 0.3758 - val_accuracy: 0.8838 - val_loss: 0.3802
# Epoch 6/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9049 - loss: 0.3229 - val_accuracy: 0.8988 - val_loss: 0.3331
# Epoch 7/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9128 - loss: 0.2850 - val_accuracy: 0.9075 - val_loss: 0.3111
# Epoch 8/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9228 - loss: 0.2551 - val_accuracy: 0.9053 - val_loss: 0.2949
# Epoch 9/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9305 - loss: 0.2282 - val_accuracy: 0.9178 - val_loss: 0.2604
# Epoch 10/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9389 - loss: 0.2029 - val_accuracy: 0.9275 - val_loss: 0.2426
# Epoch 11/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9423 - loss: 0.1869 - val_accuracy: 0.9250 - val_loss: 0.2358
# Epoch 12/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9473 - loss: 0.1724 - val_accuracy: 0.9262 - val_loss: 0.2277
# Epoch 13/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9530 - loss: 0.1553 - val_accuracy: 0.9375 - val_loss: 0.2106
# Epoch 14/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9568 - loss: 0.1430 - val_accuracy: 0.9325 - val_loss: 0.2134
# Epoch 15/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9585 - loss: 0.1354 - val_accuracy: 0.9375 - val_loss: 0.1963
# Epoch 16/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9623 - loss: 0.1245 - val_accuracy: 0.9413 - val_loss: 0.1885
# Epoch 17/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9663 - loss: 0.1150 - val_accuracy: 0.9388 - val_loss: 0.1920
# Epoch 18/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9689 - loss: 0.1059 - val_accuracy: 0.9381 - val_loss: 0.1869
# Epoch 19/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9692 - loss: 0.0994 - val_accuracy: 0.9472 - val_loss: 0.1728
# Epoch 20/30
# 345/400 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9727 - loss: 0.0933

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9557 - loss: 0.1407
# Test Accuracy: 0.9557499885559082

# %%
pred = model.predict(X_test)

# Convert probabilities → class index
pred_classes = np.argmax(pred, axis=1)

# Convert back to letters
pred_letters = le.inverse_transform(pred_classes)

print(pred_letters[:10])
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ['X' 'L' 'A' 'E' 'Q' 'E' 'O' 'Q' 'G' 'O']
